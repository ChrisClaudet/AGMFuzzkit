 (22.306011, 113.92275),
 (22.306252, 113.92355),
 (22.30648, 113.92375),
 (22.306744, 113.92375),
 (22.30751, 113.92348),
 (22.307938, 113.92332),
 (22.308205, 113.92321),
 (22.308485, 113.92311),
 (22.30873, 113.92302),
 (22.309055, 113.922905),
 (22.309422, 113.92275),
 (22.30981, 113.922615),
 (22.310299, 113.92244),
 (22.310753, 113.92226),
 (22.31123, 113.9221),
 (22.31202, 113.92181),
 (22.312351, 113.921684),
 (22.312662, 113.92156),
 (22.312992, 113.92143),
 (22.31329, 113.92133),
 (22.313744, 113.92115),
 (22.31401, 113.92106),
 (22.314396, 113.92091),
 (22.314651, 113.92081),
 (22.315052, 113.920616),
 (22.315292, 113.92065),
 (22.315525, 113.92092),
 (22.315636, 113.92127),
 (22.315762, 113.921684),
 (22.315956, 113.92225),
 (22.316154, 113.92288),
 (22.316257, 113.92319),
 (22.31641, 113.92359),
 (22.316479, 113.924065),
 (22.31638, 113.924355),
 (22.316208, 113.92473),
 (22.31599, 113.92522),
 (22.315596, 113.92609),
 (22.31542, 113.92645),
 (22.315258, 113.926834),
 (22.315094, 113.92718),
 (22.314884, 113.927635),
 (22.314909, 113.928085),
 (22.314983, 113.92834),
 (22.315132, 113.92877),
 (22.315212, 113.92903),
 (22.315292, 113.9293),
 (22.315083, 113.92906),
 (22.314846, 113.92905),
 (22.314629, 113.92913),
 (22.31409, 113.92938),
 (22.314081, 113.92938),
 (22.314095, 113.92938),
 (22.314095, 113.92938),
 (22.31409, 113.929375),
 (22.314095, 113.92938),
 (22.314095, 113.92938),
 (22.314095, 113.92938),
 (22.314095, 113.92938),
 (22.314081, 113.929344),
 (22.31409, 113.929375),
 (22.314106, 113.92938),
 (22.314047, 113.929306),
 (22.314047, 113.92929),
 (22.314095, 113.92927),
 (22.313953, 113.92933),
 (22.314056, 113.9293)]

# %%
#Get Edge Coords
StartEdgeCoords = []
EndEdgeCoords = []
for item in EdgePath:
    StartEdgeCoords.append((item[5], item[6]))
    EndEdgeCoords.append((item[7], item[8]))

    
#Adjust Final Node for Simple KML
def GPSNodeAdjust(FinalNode):
    KMLNode = []
    for item in FinalNode:
        KMLNode.append((item[1],item[0],10))
    
    return KMLNode

def FinalNodeAdjust(FinalNode):
    KMLNode = []
    for item in FinalNode:
        KMLNode.append((item[1],item[0],30))
    
    return KMLNode

# %%
#Old results import from CSV list to Tuple list
with open('FirstFuzzyMap.txt', mode='r') as FirstFuzzySnap:
    FirstSnap = FirstFuzzySnap.read().split("\n")

# %%
def GetCVSCoords(FirstSnap):    
    XCoords=[]
    YCoords=[]
    for item in FirstSnap:
        XCoords.append(float(item.split(",")[0]))
        YCoords.append(float(item.split(",")[1]))
    return list(zip(XCoords,YCoords))

# %%
FirstSnapKML=FinalNodeAdjust(GetCVSCoords(FirstSnap))

# %%
KMLNode = FinalNodeAdjust(FinalNode)
KMLGPSNode = GPSNodeAdjust(GPSCoords)

# %% [markdown]
# #Excel export for visibility test
#
# import xlwt
# from tempfile import TemporaryFile
# book = xlwt.Workbook()
# sheet1 = book.add_sheet('sheet1')
#
# for i,e in enumerate(FinalNode):
#     sheet1.write(i,2,e[0])
#     sheet1.write(i,3,e[1])
#
# name = "random6.xls"
# book.save(name)
# book.save(TemporaryFile())

# %%
l = [1,3,4,5,6]
l2 = [1,3,4]

# %%
def is_sublist(l, l2):
    if l[:len(l2)] == l2:
        print(True)
    else:
        print(False)

# %%
is_sublist(l, l2)
# Out:
# True

# %% [markdown]
# #SIMPLE KML
#
# # Create the KML document
# kml = kml.Kml(name="Tracks", open=1)
# doc = kml.newdocument(name='HKG', snippet=Snippet('HKG routes'))
# doc.lookat.gxtimespan.begin = '2018-09-01T09:00:00Z'
# doc.lookat.gxtimespan.end = '2010-09-01T10:00:00Z'
# doc.lookat.longitude = 113.9185
# doc.lookat.latitude = 22.3080
# doc.lookat.range = 3300.000000
#
# ## Create a folder
# fol = doc.newfolder(name='Tracks')
#
# ## Create a new track in the folder
# for flight_id in tracks:
#     trk = fol.newgxtrack(name='')
#
#     trk.newwhen(tracks[flight_id]['timestamps']) # Each item in the give nlist will become a new <when> tag
#     trk.newgxcoord(tracks[flight_id]['coords']) # Ditto
#
#
#     # Styling
#
#     trk.stylemap.normalstyle.linestyle.color = '99ffac59'
#     trk.stylemap.normalstyle.linestyle.width = 6
#
#     trk.stylemap.highlightstyle.iconstyle.scale = 1.2
#     trk.stylemap.highlightstyle.linestyle.color = '99ffac59'
#     trk.stylemap.highlightstyle.linestyle.width = 8
#
# ## Save the kml to file
# kml.save("hkg_routes.kml")

# %%
import simplekml

# %%
KMLGPSNode;

# %%
kml = simplekml.Kml(name="Tracks", open=1)

#Raw Tracks
linestring = kml.newlinestring(name="Raw Tracks")
linestring.coords = KMLGPSNode
linestring.altitudemode = simplekml.AltitudeMode.relativetoground
#Styling
linestring.stylemap.normalstyle.linestyle.color = '9914F0FF'
linestring.stylemap.normalstyle.linestyle.width = 3

linestring.stylemap.highlightstyle.iconstyle.scale = 1.2
linestring.stylemap.highlightstyle.linestyle.color = '9914F0FF'
linestring.stylemap.highlightstyle.linestyle.width = 3

    #linestring.style.linestyle.color = '5014F0FF'  #Yellow
    #linestring.style.linestyle.width = 3  # 3 pixels
    
#Snapped Tracks
linestring = kml.newlinestring(name="Snapped Tracks")
linestring.coords = FirstSnapKML
linestring.altitudemode = simplekml.AltitudeMode.relativetoground
#Edges?
# Styling
linestring.stylemap.normalstyle.linestyle.color = '997800F0'
linestring.stylemap.normalstyle.linestyle.width = 3

linestring.stylemap.highlightstyle.iconstyle.scale = 1.2
linestring.stylemap.highlightstyle.linestyle.color = '997800F0'
linestring.stylemap.highlightstyle.linestyle.width = 3

    #linestring.style.linestyle.color = simplekml.Color.blue  #Blue
    #linestring.style.linestyle.width = 3  # 3 pixels

kml.save("RawTracks.kml")
