# %%
FinalNode =[(22.31794416523264, 113.93113149436697),
 (22.3182816, 113.9313423),
 (22.3184715, 113.9312734),
 (22.3187461, 113.9308659),
 (22.3187391, 113.9307126),
 (22.3187391, 113.9307126),
 (22.3186031031865, 113.9302650781003),
 (22.318359299999997, 113.9294628),
 (22.31825796700223, 113.92912934560134),
 (22.3178852, 113.9280092),
 (22.3178852, 113.9280092),
 (22.317787941054362, 113.92771109622763),
 (22.317115360000003, 113.9256496),
 (22.317115360000003, 113.9256496),
 (22.317045694193894, 113.92543607064832),
 (22.3165485, 113.9239077),
 (22.3165485, 113.9239077),
 (22.31648833514023, 113.92372537035745),
 (22.3157502, 113.9214817),
 (22.31572283474452, 113.92139824906053),
 (22.3156216314455, 113.92108962740751),
 (22.3150197, 113.9206803),
 (22.31497660455223, 113.92069693137739),
 (22.314565947747084, 113.92085541188189),
 (22.3141633, 113.9209993),
 (22.313908344121067, 113.92109095721531),
 (22.31338117147352, 113.9212804769748),
 (22.312704485714278, 113.92153128571428),
 (22.312436674990234, 113.9216310766079),
 (22.311554857142852, 113.92195965714285),
 (22.311554857142852, 113.92195965714285),
 (22.311366887431717, 113.92202969789835),
 (22.309830414285713, 113.92260221428572),
 (22.309830414285713, 113.92260221428572),
 (22.3095629701004, 113.92270186860065),
 (22.3089354, 113.9229361),
 (22.308508044779813, 113.92309548269878),
 (22.30814868119932, 113.92322950782494),
 (22.307560388169932, 113.92345128016005),
 (22.307298169145405, 113.92355328772322),
 (22.307079282610662, 113.92363843822693),
 (22.306288, 113.9235371),
 (22.3062798, 113.9234529),
 (22.3062798, 113.9234529),
 (22.306191372805962, 113.92317859685696),
 (22.306088605780378, 113.92285981123423),
 (22.3058448, 113.9221038),
 (22.30584242858181, 113.92209644554059),
 (22.30549275, 113.92101195),
 (22.305486364151786, 113.92099214436733),
 (22.30508065, 113.91973385),
 (22.30507682740973, 113.91972199471098),
 (22.30487583366411, 113.91909863756942),
 (22.3041902, 113.9169722),
 (22.3041902, 113.9169722),
 (22.304140917980693, 113.91681938418415),
 (22.303149933333337, 113.9137464),
 (22.303149933333337, 113.9137464),
 (22.30303994815952, 113.91340531049772),
 (22.302359666666668, 113.91129559999999),
 (22.302359666666668, 113.91129559999999),
 (22.302196670234437, 113.91079011030523),
 (22.30197263333333, 113.91009533333332),
 (22.30188132052722, 113.90981215760613),
 (22.3015937, 113.9089202),
 (22.301553874052242, 113.90879668956033),
 (22.301448766516067, 113.90847072423537),
 (22.2995529, 113.9025915),
 (22.2995529, 113.9025915),
 (22.299334479614416, 113.90191404195649),
 (22.2991579, 113.9013664),
 (22.2991579, 113.9013664),
 (22.299073933888888, 113.90110599294742),
 (22.2990025103545, 113.90088448462903),
 (22.298918056704625, 113.90062256555534),
 (22.298756464869705, 113.90012146535604),
 (22.298659411550833, 113.89982051508215),
 (22.298577755975508, 113.89956730865512),
 (22.298484311501724, 113.8992774519453),
 (22.298420464084362, 113.89907940275546),
 (22.2979661, 113.897781),
 (22.2979661, 113.897781),
 (22.29790766085668, 113.89775527289385),
 (22.297562, 113.8976031),
 (22.29748621180576, 113.89763306493477),
 (22.297260896146085, 113.8977221496414),
 (22.297048472683226, 113.89780613706552),
 (22.29682558663779, 113.89788991398466),
 (22.296614912881623, 113.89796766961888),
 (22.2964615, 113.898793),
 (22.2964615, 113.898793),
 (22.2981028, 113.9026214),
 (22.2981028, 113.9026214),
 (22.2981028, 113.9026214),
 (22.3050547, 113.9234466),
 (22.3050547, 113.9234466),
 (22.3050547, 113.9234466)]


GPSCoords = [(22.334427, 114.01766),
 (22.332413, 114.01133),
 (22.330364, 114.004974),
 (22.32843, 113.99893),
 (22.325409, 113.98965),
 (22.323473, 113.983864),
 (22.321472, 113.97766),
 (22.318726, 113.96927),
 (22.316816, 113.96342),
 (22.315327, 113.95869),
 (22.313465, 113.95294),
 (22.311584, 113.94705),
 (22.31016, 113.94262),
 (22.308884, 113.93851),
 (22.307465, 113.933815),
 (22.306366, 113.93017),
 (22.304443, 113.923676),
 (22.303116, 113.91938),
 (22.300587, 113.911606),
 (22.297289, 113.90138),
 (22.296913, 113.90019),
 (22.296532, 113.89904),
 (22.29633, 113.89846),
 (22.296322, 113.89815),
 (22.296625, 113.897995),
 (22.296833, 113.89791),
 (22.29705, 113.89781),
 (22.297264, 113.89773),
 (22.297485, 113.89763),
 (22.297718, 113.89754),
 (22.297943, 113.897675),
 (22.298044, 113.897995),
 (22.298288, 113.89875),
 (22.2984, 113.899086),
 (22.298464, 113.899284),
 (22.298557, 113.899574),
 (22.29863, 113.89983),
 (22.29873, 113.90013),
 (22.298895, 113.90063),
 (22.298973, 113.900894),
 (22.299046, 113.901115),
 (22.299139, 113.90138),
 (22.299208, 113.90162),
 (22.299316, 113.90192),
 (22.299614, 113.902855),
 (22.30001, 113.90409),
 (22.30142, 113.90848),
 (22.301525, 113.908806),
 (22.30172, 113.909386),
 (22.301857, 113.90982),
 (22.302074, 113.91049),
 (22.302166, 113.9108),
 (22.30243, 113.91159),
 (22.302704, 113.91245),
 (22.303013, 113.913414),
 (22.303387, 113.91458),
 (22.30363, 113.91533),
 (22.304108, 113.91683),
 (22.30434, 113.91752),
 (22.304546, 113.91816),
 (22.304853, 113.919106),
 (22.305052, 113.91973),
 (22.305225, 113.92029),
 (22.305462, 113.921),
 (22.305609, 113.92147),
 (22.305819, 113.922104),
 (22.305954, 113.92254),
 (22.306057, 113.92287),
 (22.306156, 113.92319),
 (22.306252, 113.92349),
 (22.306425, 113.92372),
 (22.306686, 113.92377),
 (22.307076, 113.92363),
 (22.307293, 113.92354),
 (22.307556, 113.92344),
 (22.308147, 113.923225),
 (22.308506, 113.92309),
 (22.308996, 113.922905),
 (22.309566, 113.92271),
 (22.310108, 113.92251),
 (22.31075, 113.922264),
 (22.311367, 113.92203),
 (22.311676, 113.921906),
 (22.312065, 113.92177),
 (22.31244, 113.92164),
 (22.313034, 113.92141),
 (22.313381, 113.92128),
 (22.313908, 113.92109),
 (22.31425, 113.92096),
 (22.31456, 113.92084),
 (22.314972, 113.920685),
 (22.315487, 113.92083),
 (22.31559, 113.9211),
 (22.315687, 113.92141),
 (22.315819, 113.92182),
 (22.316444, 113.92374),
 (22.316551, 113.92409),
 (22.316782, 113.924805),
 (22.317003, 113.92545),
 (22.317364, 113.9266),
 (22.317547, 113.92715),
 (22.31773, 113.92773),
 (22.317879, 113.92821),
 (22.31805, 113.92871),
 (22.31819, 113.92915),
 (22.31847, 113.93004),
 (22.318554, 113.93028),
 (22.318703, 113.930756),
 (22.318691, 113.93101),
 (22.31844, 113.9313),
 (22.318178, 113.93139),
 (22.317913, 113.931366),
 (22.3179, 113.93114),
 (22.31784, 113.93088)]

# %%
#Get Edge Coords
#StartEdgeCoords = []
#EndEdgeCoords = []
#for item in EdgePath:
#    StartEdgeCoords.append((item[5], item[6]))
#    EndEdgeCoords.append((item[7], item[8]))

    
#Adjust Final Node for Simple KML
def GPSNodeAdjust(FinalNode):
    KMLNode = []
    for item in FinalNode:
        KMLNode.append((item[1],item[0],10))
    
    return KMLNode

def FinalNodeAdjust(FinalNode):
    KMLNode = []
    for item in FinalNode:
        KMLNode.append((item[1],item[0],30))
    
    return KMLNode

# %%
#Old results import from CSV list to Tuple list
with open('FirstFuzzyMap.txt', mode='r') as FirstFuzzySnap:
    FirstSnap = FirstFuzzySnap.read().split("\n")

# %%
def GetCVSCoords(FirstSnap):    
    XCoords=[]
    YCoords=[]
    for item in FirstSnap:
        XCoords.append(float(item.split(",")[0]))
        YCoords.append(float(item.split(",")[1]))
    return list(zip(XCoords,YCoords))

# %%
FirstSnapKML=FinalNodeAdjust(GetCVSCoords(FirstSnap))

# %%
KMLNode = FinalNodeAdjust(FinalNode)
KMLGPSNode = GPSNodeAdjust(GPSCoords)

# %% [markdown]
# #Excel export for visibility test
#
# import xlwt
# from tempfile import TemporaryFile
# book = xlwt.Workbook()
# sheet1 = book.add_sheet('sheet1')
#
# for i,e in enumerate(FinalNode):
#     sheet1.write(i,2,e[0])
#     sheet1.write(i,3,e[1])
#
# name = "random6.xls"
# book.save(name)
# book.save(TemporaryFile())

# %%
l = [1,3,4,5,6]
l2 = [1,3,4]

# %%
def is_sublist(l, l2):
    if l[:len(l2)] == l2:
        print(True)
    else:
        print(False)

# %%
is_sublist(l, l2)
# Out:
# True

# %% [markdown]
# #SIMPLE KML
#
# # Create the KML document
# kml = kml.Kml(name="Tracks", open=1)
# doc = kml.newdocument(name='HKG', snippet=Snippet('HKG routes'))
# doc.lookat.gxtimespan.begin = '2018-09-01T09:00:00Z'
# doc.lookat.gxtimespan.end = '2010-09-01T10:00:00Z'
# doc.lookat.longitude = 113.9185
# doc.lookat.latitude = 22.3080
# doc.lookat.range = 3300.000000
#
# ## Create a folder
# fol = doc.newfolder(name='Tracks')
#
# ## Create a new track in the folder
# for flight_id in tracks:
#     trk = fol.newgxtrack(name='')
#
#     trk.newwhen(tracks[flight_id]['timestamps']) # Each item in the give nlist will become a new <when> tag
#     trk.newgxcoord(tracks[flight_id]['coords']) # Ditto
#
#
#     # Styling
#
#     trk.stylemap.normalstyle.linestyle.color = '99ffac59'
#     trk.stylemap.normalstyle.linestyle.width = 6
#
#     trk.stylemap.highlightstyle.iconstyle.scale = 1.2
#     trk.stylemap.highlightstyle.linestyle.color = '99ffac59'
#     trk.stylemap.highlightstyle.linestyle.width = 8
#
# ## Save the kml to file
# kml.save("hkg_routes.kml")

# %%
import simplekml

# %%
KMLGPSNode;

# %%
kml = simplekml.Kml(name="Tracks", open=1)

#Raw Tracks
linestring = kml.newlinestring(name="Raw Tracks")
linestring.coords = KMLGPSNode
linestring.altitudemode = simplekml.AltitudeMode.relativetoground
#Styling
linestring.stylemap.normalstyle.linestyle.color = '9914F0FF'
linestring.stylemap.normalstyle.linestyle.width = 8

linestring.stylemap.highlightstyle.iconstyle.scale = 1.2
linestring.stylemap.highlightstyle.linestyle.color = '9914F0FF'
linestring.stylemap.highlightstyle.linestyle.width = 8

    #linestring.style.linestyle.color = '5014F0FF'  #Yellow
    #linestring.style.linestyle.width = 3  # 3 pixels
    
#Snapped Tracks
linestring = kml.newlinestring(name="Snapped Tracks")
linestring.coords = KMLNode
linestring.altitudemode = simplekml.AltitudeMode.relativetoground
#Edges?
# Styling
linestring.stylemap.normalstyle.linestyle.color = '99F0FF14'
linestring.stylemap.normalstyle.linestyle.width = 8

linestring.stylemap.highlightstyle.iconstyle.scale = 1.2
linestring.stylemap.highlightstyle.linestyle.color = '99F0FF14'
linestring.stylemap.highlightstyle.linestyle.width = 8

    #linestring.style.linestyle.color = simplekml.Color.blue  #Blue
    #linestring.style.linestyle.width = 3  # 3 pixels

kml.save("Flight1.kml")
